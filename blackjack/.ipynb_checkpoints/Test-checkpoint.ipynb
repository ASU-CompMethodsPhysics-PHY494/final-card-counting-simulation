# %%
import blackjacktools as bj
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pri = 5000
s = 120
l = 210
hands = (80*8)
decks = 6

table = bj.Table()
table.set_players([bj.Player(s,l,bank_roll=pri) for _ in range(5)])
table.shuffle_deck(n=decks)
bal = table.run(max_hands=hands)
plt.plot(bal.T)
plt.plot([x for x in range(len(bal[0]))],[pri for x in range(len(bal[0]))],'r--')
plt.plot([x for x in range(len(bal[0]))],[0 for x in range(len(bal[0]))],'b--')
plt.show()

# %%
pri = 5000
s = 50
l = 500
hands = (80*8)
decks = 6

table = bj.Table()
table.set_players([bj.Player(s,l,bank_roll=pri) for _ in range(5)])
table.shuffle_deck(n=decks)
bal = table.run(max_hands=hands)
plt.plot(bal.T)
plt.plot([x for x in range(len(bal[0]))],[pri for x in range(len(bal[0]))],'r--')
plt.plot([x for x in range(len(bal[0]))],[0 for x in range(len(bal[0]))],'b--')
plt.show()

# %%
pri = 5000
s = 145
l = 165
hands = (80*8*5*52)
decks = 6

table = bj.Table()
table.set_players([bj.Player(s,l,bank_roll=pri) for _ in range(5)])
table.shuffle_deck(n=decks)
bal = table.run(max_hands=hands)
plt.plot(bal.T)
plt.plot([x for x in range(len(bal[0]))],[pri for x in range(len(bal[0]))],'r--')
plt.plot([x for x in range(len(bal[0]))],[0 for x in range(len(bal[0]))],'b--')
plt.show()

# %%
pri = 5000
s = 100
l = 300
hands = (80*8)
decks = 6

table = bj.Table()
table.set_players([bj.Player(s,l,bank_roll=pri) for _ in range(5)])
table.shuffle_deck(n=decks)
bal = table.run(max_hands=hands)
plt.plot(bal.T)
plt.plot([x for x in range(len(bal[0]))],[pri for x in range(len(bal[0]))],'r--')
plt.plot([x for x in range(len(bal[0]))],[0 for x in range(len(bal[0]))],'b--')
plt.show()

# %%
T = bj.Table()
T.set_players([bj.Player(70,90) for _ in range(1)])
T.shuffle_deck()
T.run(max_hands = 10)
# Out:
# 19
# 1
# 18
# 1
# 26
# -1
# 12
# 2
# 14
# 3
# 17
# 4
# 16
# 0
# 25
# 0
# 20
# 0
# 13
# 0
# 18
# 1
# 12
# 3
# 22
# 2
# 15
# 2
# 15
# 1
# 25
# 0
# 11
# 2
# 18
# 2
# 26
# -1
# array([[ 5080.,  5000.,  4930.,  4860.,  4790.,  4860.,  4860.,  4790.,
#          4860.,  4860.]])
